# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

query = "(from:elonmusk) until:2020-01-01 since:2010-01-01"
tweets = []
limit = 5000


for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    
    # print(vars(tweet))
    # break
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.date, tweet.user.username, tweet.content])
        
df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet'])
print(df)

# to save to csv
# df.to_csv('tweets.csv')

# to save to csv
# df.to_csv('tweets.csv')

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

query = 'President of Nigeria'  #"(from:elonmusk) until:2020-01-01 since:2010-01-01")
tweets = []
limit = 5000


for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    
    # print(vars(tweet))
    # break
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.date, tweet.user.username, tweet.content])
        
df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet', ])

# %%
df
# Out:
#                           Date             User  \
# 0    2022-05-13 14:56:21+00:00       MikeDamini
# 1    2022-05-13 14:55:51+00:00     Psalmist1904
# 2    2022-05-13 14:55:49+00:00         Olubaks1
# 3    2022-05-13 14:55:27+00:00          Sohmtoh
# 4    2022-05-13 14:55:06+00:00        Nkemchor_
# ...                        ...              ...
# 4995 2022-05-01 23:07:37+00:00          ogoandy
# 4996 2022-05-01 22:51:31+00:00     Alexnwokedi2
# 4997 2022-05-01 22:39:22+00:00  iam_vicbababmfr
# 4998 2022-05-01 22:38:50+00:00  MrRightWrighter
# 4999 2022-05-01 22:30:33+00:00     Alexnwokedi2
#
#                                                   Tweet
# 0     @sam_adeyemi Come and take my Position as the ...
# 1     Lord lugard wanted one Nigeria, he didn't even...
# 2     So none of these people that wanna become The ...
# 3     Please retweet 🤲🤲\n\nSuper clean 2008 Toyota C...
# 4     This is a scam. Peter Obi is well capable to h...
# ...                                                 ...
# 4995  Chief of Staff to the President of Nigeria, Pr...
# 4996  @ChinonyelumH @moneymagneta @adaigbo_2022 You ...
# 4997  @renoomokri Going down from mountain🏔 ,to moun...
# 4998  @Imranmuhdz @woye1 @DaminaboEric @DOlusegun @a...
# 4999  @ChinonyelumH @moneymagneta @adaigbo_2022 Pete...
#
# [5000 rows x 3 columns]

# %%
df.to_csv('tweets.csv')

# %%
data= pd.read_csv('tweets.csv')

# %%
data
# Out:
#       Unnamed: 0                       Date             User  \
# 0              0  2022-05-13 14:56:21+00:00       MikeDamini
# 1              1  2022-05-13 14:55:51+00:00     Psalmist1904
# 2              2  2022-05-13 14:55:49+00:00         Olubaks1
# 3              3  2022-05-13 14:55:27+00:00          Sohmtoh
# 4              4  2022-05-13 14:55:06+00:00        Nkemchor_
# ...          ...                        ...              ...
# 4995        4995  2022-05-01 23:07:37+00:00          ogoandy
# 4996        4996  2022-05-01 22:51:31+00:00     Alexnwokedi2
# 4997        4997  2022-05-01 22:39:22+00:00  iam_vicbababmfr
# 4998        4998  2022-05-01 22:38:50+00:00  MrRightWrighter
# 4999        4999  2022-05-01 22:30:33+00:00     Alexnwokedi2
#
#                                                   Tweet
# 0     @sam_adeyemi Come and take my Position as the ...
# 1     Lord lugard wanted one Nigeria, he didn't even...
# 2     So none of these people that wanna become The ...
# 3     Please retweet 🤲🤲\n\nSuper clean 2008 Toyota C...
# 4     This is a scam. Peter Obi is well capable to h...
# ...                                                 ...
# 4995  Chief of Staff to the President of Nigeria, Pr...
# 4996  @ChinonyelumH @moneymagneta @adaigbo_2022 You ...
# 4997  @renoomokri Going down from mountain🏔 ,to moun...
# 4998  @Imranmuhdz @woye1 @DaminaboEric @DOlusegun @a...
# 4999  @ChinonyelumH @moneymagneta @adaigbo_2022 Pete...
#
# [5000 rows x 4 columns]
